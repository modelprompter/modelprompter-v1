# %% [markdown]
# Adapted from: https://colab.research.google.com/drive/1AfAmwLMd_Vx33O9IwY2TmO9wKZ8ABRRa

# %% [markdown]
# # Step 1: **Don't start yet**. First, get your Hugging Face API Key from [https://huggingface.co/settings/tokens](https://huggingface.co/settings/tokens)
# You'll need the API key to download the Stable Diffusion model. If you don't have an account yet, create a free account and then revisit the link to generate a new token. Once you've copied the key visit Step 2 below

# %%
# Prepares the GPU
# !nvidia-smi

# %%
# Restarts OS (this cell will break the notebook...just start running again)
import os
os.kill(os.getpid(), 9)

# %%
# Clones AUTOMATIC1111's Stable Diffusion python server,
# and reverts toa state with blocks preconfigured for Model Prompter
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd stable-diffusion-webui
# !git reset --hard 74f940e8183e0745029ee38e7542237205c927d8

# %%
# Installs dependencies
# !pip install -r requirements.txt
# !mkdir repositories
# !git clone https://github.com/CompVis/stable-diffusion.git repositories/stable-diffusion
# !git clone https://github.com/CompVis/taming-transformers.git repositories/taming-transformers
# !git clone https://github.com/sczhou/CodeFormer.git repositories/CodeFormer
# !git clone https://github.com/salesforce/BLIP.git repositories/BLIP
# !pip install -r repositories/CodeFormer/requirements.txt

# %% [markdown]
# # Step 2: Paste the token in between the "" in user_token below
# ### ⚠ Be careful not to share your token! ⚠
# Once you've pasted it go back up to step 1 and run thru all the cells until you get to **Step 3**. Note that execution may stop in 2 cells, just start running again after.

# %%
# Downloads the model from huggingface. See link at the start for different ways.
user_token = ""
user_header = f"\"Authorization: Bearer {user_token}\""
# !wget --header={user_header} https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt -O ./model.ckpt

# %%
# Restart (it's normal that it breaks)
import os
os.kill(os.getpid(), 9)

# %%
# Changes into Web UI directory and download updates
# !ls -la /content/stable-diffusion-webui/model.ckpt
# %cd stable-diffusion-webui

# %%
# Starts the server and launches the Web UI at https://nnn.gradio.app
# The API to the server is at https://nnn.gradio.app/api/predict
import sys
sys.argv = ['webui.py', "--share", "--opt-split-attention"]

import webui
webui.webui()

# %% [markdown]
# # Step 3: Use [https://nnn.gradio.app/api/predict](https://nnn.gradio.app/api/predict) within your blocks to use the GPU
# ⚠ **Note that this is a public URL,** this means that although unlikely, anyone else can POST your API just as you can. Notes on securing this will be provided soon.

# %% [markdown]
# (rest of original documentation) commands for ***after*** you have gotten done with a session
# ============================================================================

# %% [markdown]
# Zip images for downloading on local drive (click the folder icon on the left, the one below {x})

# %%
# !zip -r /content/stable-diffusion-webui /content/stable-diffusion-webui/outputs

# %% [markdown]
# Save images to Google Drive **Warning: this will cause google to scan your drive, so if you intend to use this and worry about that kind of stuff, probablly just set this up on a clean account that's just for this colab**

# %%
from google.colab import drive # type: ignore

try:
   drive_path = "/content/drive"
   drive.mount(drive_path,force_remount=False)
except:
   print("...error mounting drive or with drive path variables")

# !cp -r "/content/stable-diffusion-webui/outputs" "/content/drive/MyDrive"
